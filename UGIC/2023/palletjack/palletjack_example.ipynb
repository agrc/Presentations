# %%
import pandas as pd
from palletjack import extract, transform, load

# %%
pg_loader = extract.PostgresLoader('opensgid.agrc.utah.gov', 'opensgid', 'agrc', 'agrc')
counties_df = pg_loader.read_table_into_dataframe('boundaries.county_boundaries', 'xid', '26912', 'shape')

# %%
counties_df
# Out:
#     countynbr     entitynbr  entityyr        name  fips stateplane
# xid
# 1          20  2.010201e+09    2010.0     SANPETE  39.0    Central  \
# 2          11  2.010111e+09    2010.0        IRON  21.0      South
# 3          13  2.010131e+09    2010.0        KANE  25.0      South
# 4          29  2.010291e+09    2010.0       WEBER  57.0      North
# 5          19  2.006191e+09    2006.0    SAN JUAN  37.0      South
# 6          09  2.010091e+09    2010.0    GARFIELD  17.0      South
# 7          17  2.010171e+09    2010.0        RICH  33.0      North
# 8          22  2.010221e+09    2010.0      SUMMIT  43.0      North
# 9          23  2.010231e+09    2010.0      TOOELE  45.0    Central
# 10         01  2.010011e+09    2010.0      BEAVER   1.0      South
# 11         02  2.010021e+09    2010.0   BOX ELDER   3.0      North
# 12         03  2.010031e+09    2010.0       CACHE   5.0      North
# 13         24  2.010241e+09    2010.0      UINTAH  47.0    Central
# ...
